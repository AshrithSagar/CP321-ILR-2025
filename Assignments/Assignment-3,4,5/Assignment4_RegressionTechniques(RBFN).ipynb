# %% [markdown]
# # CP321-ILR: Assigment-4

# %%
# %load_ext autoreload
# %autoreload 2

from utils.utils import (
    fit_rbfn,
    different_initial_points_rbfn,
    generalisation_rbfn,
)

# %% [markdown]
# ## Dataset "C"

# %% [markdown]
# ### 1. GAS point
#
# Does the system have a GAS (Global asymptotic Stable) Point ? Explain.

# %% [markdown]
# #### Plots

# %%
fit_rbfn(dataset="c", n=4, bias=False)

# %% [markdown]
# #### Analysis

# %% [markdown]
# No, the system doesn't have a global asymptotic stable point.
#
# As seen from the vector field, the arrows are diverging near the outer areas of the plot.

# %% [markdown]
# ### 2. Different initial points
#
# Try different initial points, and simulate the process.

# %% [markdown]
# #### Plots

# %%
different_initial_points_rbfn(dataset="c", initial_points=[1, 2], n=4, bias=False)

# %% [markdown]
# #### Analysis

# %% [markdown]
# ### 3. Generalization of the algorithm
#
# Try changing the number of gaussians and comment on the generalization of the algorithm.

# %% [markdown]
# #### Plots

# %%
generalisation_rbfn(dataset="c", n_values=[2, 4], bias=False)

# %% [markdown]
# #### Analysis

# %% [markdown]
# ## Dataset "J"

# %% [markdown]
# ### 1. GAS point
#
# Does the system have a GAS (Global asymptotic Stable) Point ? Explain.

# %% [markdown]
# #### Plots

# %%
fit_rbfn(dataset="j", n=4, bias=False)

# %% [markdown]
# #### Analysis

# %% [markdown]
# No, the system doesn't have a global asymptotic stable point.
#
# As seen from the vector field, the arrows are diverging near the outer areas of the plot.

# %% [markdown]
# ### 2. Different initial points
#
# Try different initial points, and simulate the process.

# %% [markdown]
# #### Plots

# %%
different_initial_points_rbfn(dataset="j", initial_points=[1, 2], n=4, bias=False)

# %% [markdown]
# #### Analysis

# %% [markdown]
# ### 3. Generalization of the algorithm
#
# Try changing the number of gaussians and comment on the generalization of the algorithm.

# %% [markdown]
# #### Plots

# %%
generalisation_rbfn(dataset="j", n_values=[2, 4], bias=False)

# %% [markdown]
# #### Analysis

# %% [markdown]
# ## Dataset "S"

# %% [markdown]
# ### 1. GAS point
#
# Does the system have a GAS (Global asymptotic Stable) Point ? Explain.

# %% [markdown]
# #### Plots

# %%
fit_rbfn(dataset="s", n=4, bias=False)

# %% [markdown]
# #### Analysis

# %% [markdown]
# No, the system doesn't have a global asymptotic stable point.
#
# As seen from the vector field, the arrows are diverging towards the bottom near the outer areas of the plot.

# %% [markdown]
# ### 2. Different initial points
#
# Try different initial points, and simulate the process.

# %% [markdown]
# #### Plots

# %%
different_initial_points_rbfn(dataset="s", initial_points=[1, 2], n=4, bias=False)

# %% [markdown]
# #### Analysis

# %% [markdown]
# ### 3. Generalization of the algorithm
#
# Try changing the number of gaussians and comment on the generalization of the algorithm.

# %% [markdown]
# #### Plots

# %%
generalisation_rbfn(dataset="s", n_values=[2, 4], bias=False)

# %% [markdown]
# #### Analysis
