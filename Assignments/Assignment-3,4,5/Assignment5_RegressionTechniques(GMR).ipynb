# %% [markdown]
# # CP321-ILR: Assigment-5

# %%
# %load_ext autoreload
# %autoreload 2

from utils.utils import different_initial_points_gmr, fit_gmr, generalisation_gmr

# %% [markdown]
# # PART1: GMR (Gaussian Mixture Regression)

# %% [markdown]
# ![Screenshot 2025-02-12 at 11.25.42 AM.png](data:image/png;base64,...)

# %% [markdown]
# ![Screenshot 2025-02-12 at 11.28.09 AM.png](data:image/png;base64,...)

# %% [markdown]
# ## Dataset "C"

# %% [markdown]
# ### 1. GAS point
#
# Does the system have a GAS (Global asymptotic Stable) Point ? Explain.

# %% [markdown]
# #### Plots

# %%
fit_gmr(dataset="c", n=10)
# Out:
# posterioir: [0.12775175 0.07133509 0.15367848 0.04553837 0.0766427  0.14084487
#  0.17637243 0.06757691 0.11661229 0.02364711]
# shapes of means: (10, 4)
# shapes of covariances: (10, 4, 4)
# /Users/ashrith/Developer/GitHub/AshrithSagar/CP321-ILR-2025/Assignments/Assignment-3,4,5/utils/models.py:306: RuntimeWarning: overflow encountered in matmul
#   numerator += mean[d:] + prior * inv_cov_yy @ (x - mean[:d])
# /Users/ashrith/Developer/GitHub/AshrithSagar/CP321-ILR-2025/Assignments/Assignment-3,4,5/utils/models.py:306: RuntimeWarning: invalid value encountered in add
#   numerator += mean[d:] + prior * inv_cov_yy @ (x - mean[:d])

# %% [markdown]
# #### Analysis

# %% [markdown]
# ### 2. Different initial points
#
# Try different initial points, and simulate the process.

# %% [markdown]
# #### Plots

# %%
different_initial_points_gmr(dataset="c", initial_points=[1, 2], n=10)
# Out:
# posterioir: [0.22009578 0.07907558 0.02516005 0.08795767 0.06219753 0.12524322
#  0.07212985 0.16221006 0.0109735  0.15495677]
# shapes of means: (10, 4)
# shapes of covariances: (10, 4, 4)
# /Users/ashrith/Developer/GitHub/AshrithSagar/CP321-ILR-2025/Assignments/Assignment-3,4,5/utils/models.py:306: RuntimeWarning: overflow encountered in matmul
#   numerator += mean[d:] + prior * inv_cov_yy @ (x - mean[:d])
# /Users/ashrith/Developer/GitHub/AshrithSagar/CP321-ILR-2025/Assignments/Assignment-3,4,5/utils/models.py:306: RuntimeWarning: invalid value encountered in add
#   numerator += mean[d:] + prior * inv_cov_yy @ (x - mean[:d])

# %% [markdown]
# ### 3. Generalization of the algorithm
#
# Try changing the number of gaussians and comment on the generalization of the algorithm.

# %% [markdown]
# #### Plots

# %%
generalisation_gmr(dataset="c", n_values=[2, 4, 6, 8])

# %% [markdown]
# #### Analysis

# %% [markdown]
# ## Dataset "J"

# %% [markdown]
# ### 1. GAS point
#
# Does the system have a GAS (Global asymptotic Stable) Point ? Explain.

# %% [markdown]
# #### Plots

# %%
fit_gmr(dataset="j", n=10)

# %% [markdown]
# #### Analysis

# %% [markdown]
# ### 2. Different initial points
#
# Try different initial points, and simulate the process.

# %% [markdown]
# #### Plots

# %%
different_initial_points_gmr(dataset="j", initial_points=[1, 2], n=10)

# %% [markdown]
# ### 3. Generalization of the algorithm
#
# Try changing the number of gaussians and comment on the generalization of the algorithm.

# %% [markdown]
# #### Plots

# %%
generalisation_gmr(dataset="j", n_values=[2, 4, 6, 8])

# %% [markdown]
# #### Analysis

# %% [markdown]
# ## Dataset "S"

# %% [markdown]
# ### 1. GAS point
#
# Does the system have a GAS (Global asymptotic Stable) Point ? Explain.

# %% [markdown]
# #### Plots

# %%
fit_gmr(dataset="s", n=10)

# %% [markdown]
# #### Analysis

# %% [markdown]
# ### 2. Different initial points
#
# Try different initial points, and simulate the process.

# %% [markdown]
# #### Plots

# %%
different_initial_points_gmr(dataset="s", initial_points=[1, 2], n=10)

# %% [markdown]
# ### 3. Generalization of the algorithm
#
# Try changing the number of gaussians and comment on the generalization of the algorithm.

# %% [markdown]
# #### Plots

# %%
generalisation_gmr(dataset="s", n_values=[2, 4, 6, 8])

# %% [markdown]
# #### Analysis
