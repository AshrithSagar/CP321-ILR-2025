# %% [markdown]
# # CP321-ILR: Assigment-6

# %%
# %load_ext autoreload
# %autoreload 2

from utils.utils import different_initial_points_gpr, fit_gpr

# %% [markdown]
# # GPR (Gaussian Process Regression)

# %% [markdown]
# ![Screenshot 2025-02-17 at 11.50.20 AM.png](data:image/png;base64,...)

# %% [markdown]
# ![Screenshot 2025-02-17 at 11.08.10 AM.png](data:image/png;base64,...)

# %%
from sklearn.gaussian_process.kernels import RBF

rbf_kernel = RBF(length_scale=1.0)

# %% [markdown]
# ## Dataset "C"

# %% [markdown]
# ### 1. GAS point
#
# Does the system have a GAS (Global asymptotic Stable) Point ? Explain.

# %% [markdown]
# #### Plots

# %%
fit_gpr(dataset="c", kernel=rbf_kernel, show_prior_posterior=False)

# %% [markdown]
# #### Analysis

# %% [markdown]
# ### 2. Different initial points
#
# Try different initial points, and simulate the process.

# %% [markdown]
# #### Plots

# %%
different_initial_points_gpr(dataset="c", kernel=rbf_kernel, initial_points=[2, 4])

# %% [markdown]
# ### 3. Generalization of the algorithm
#
# Try different kernels and comment on the generalization of the algorithm.

# %% [markdown]
# #### Plots

# %% [markdown]
# #### Analysis

# %% [markdown]
# ## Dataset "J"

# %% [markdown]
# ### 1. GAS point
#
# Does the system have a GAS (Global asymptotic Stable) Point ? Explain.

# %% [markdown]
# #### Plots

# %%
fit_gpr(dataset="j", kernel=rbf_kernel, show_prior_posterior=False)

# %% [markdown]
# #### Analysis

# %% [markdown]
# ### 2. Different initial points
#
# Try different initial points, and simulate the process.

# %% [markdown]
# #### Plots

# %%
different_initial_points_gpr(dataset="j", kernel=rbf_kernel, initial_points=[2, 4])

# %% [markdown]
# ### 3. Generalization of the algorithm
#
# Try different kernels and comment on the generalization of the algorithm.

# %% [markdown]
# #### Plots

# %% [markdown]
# #### Analysis

# %% [markdown]
# ## Dataset "S"

# %% [markdown]
# ### 1. GAS point
#
# Does the system have a GAS (Global asymptotic Stable) Point ? Explain.

# %% [markdown]
# #### Plots

# %%
fit_gpr(dataset="s", kernel=rbf_kernel, show_prior_posterior=False)

# %% [markdown]
# #### Analysis

# %% [markdown]
# ### 2. Different initial points
#
# Try different initial points, and simulate the process.

# %% [markdown]
# #### Plots

# %%
different_initial_points_gpr(dataset="s", kernel=rbf_kernel, initial_points=[2, 4])

# %% [markdown]
# ### 3. Generalization of the algorithm
#
# Try different kernels and comment on the generalization of the algorithm.

# %% [markdown]
# #### Plots

# %% [markdown]
# #### Analysis
